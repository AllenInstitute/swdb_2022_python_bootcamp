# %% [markdown]
# <div style="padding: 5px; padding-left: 10px;">
#
# <center><h2>Table of Contents & Jumplinks</h2></center>
# <h4><a href='#introduction'>Introduction</a></h4>
# <li>background
# <li>why use pandas
# <li>resources & documentation
#
# <h4><a href='#imports'>Imports</a></h4>
# <h4><a href='#dataload'>Data Loading</a></h4>
#
# <h4><a href='#explore'>Explore the dataset & basic functionality</a></h4>
# <li>view the dataframe, how many rows & columns
# <li>view specifics about columns
# <li>get data types and unique entries
# <li>descriptive statistics
#
# <h4><a href='#dataselection'>Data Selection</a></h4>
# <li>select data by index/position or by labels/names
# <li>conditional selection
# <li>multiple condition selection
#
#
# <h4><a href='#manipulate'>Data Manipulation & Cleaning</a></h4>
# <li>drop columns, rows, nans
# <li>add new columns
# <li>melt & pivot
#
# <h4><a href='#plot'>Data Aggregation & Plotting</a></h4>
# <li>pivot_table
# <li>grouby
# <li>aggregation
# <li>sort values
#
# <h4><a href='#table'>Table Manipulations</a></h4>
# <li>join & merge tables
# <li>create dataframe from scratch
# <li>saving dataframes

# %% [markdown]
# <a id='introduction'></a>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
#
# <center><h1>Introduction to Pandas</h1></center>
#
#
# **<code>[pandas](https://pandas.pydata.org/)</code>** is a library with high-level data structures and manipulation tools:
#
# * Data loading/saving
# * Data exploration
# * Filtering, selecting
# * Plotting/visualization
# * Computing summary statistics
# * Groupby operations
#
#
#
# **DataFrame Object**
#
# A Pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns like a spreadsheet or SQL table, or a dict of Series objects. Pandas DataFrame consists of three principal components, the data, rows, and columns.
# ***
# Key takeaways:
# * Represents a tabular, spreadsheet-like data structure
# * Ordered collection of columns
# * Each column can be a different value type (numeric, string, boolean, etc.)
#
#
# <img src="example_images/dataframe_example.png">

# %% [markdown]
# <a id='why_use_pandas'></a>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
#
# **Why Use Pandas**
#
# * real world data is messy! Pandas offers many tools to clean, transform and manipulate data to clean it up for analysis. Pandas handles missing data and can handle single or multi-dimensional data.
# * vectorized mathematical operations optimizes computation performance and execution speed. Pandas is built on top of numpy and uses numpy array for object manipulation and computation.

# %% [markdown]
# <a id='pandas_resources'></a>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
#
#
# **Documentation & Resources**
#
# This introduction will only just scratch the surface of Pandas functionality. For more information, check out the [full documentation](https://pandas.pydata.org/docs/reference/index.html)
#
# This [cheat-sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) is also highly recommended to print out and keep handy as a resource.
# <p>Or check out the <a href="http://pandas.pydata.org/pandas-docs/stable/10min.html">'10 minutes to Pandas'</a> tutorial here (note: title may mischaracterize time investment).

# %% [markdown]
# <a id='imports'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background: #e6f2ff">
# <h2> Import Packages </h2>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Library imports**
# Here we'll load in the libraries we'll use to shape and explore the data

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <a id='dataload'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6f2ff">
# <h2> Load dataset </h2>
#
# Our first step is loading in the data from a CSV
#
# Pandas has great [tools for automatically interpretting data from many sources](https://pandas.pydata.org/docs/reference/io.html)
#
# * pd.read_csv
# * pd.read_excel
# * pd.read_pickle
# * pd.read_json
#
#  we will use pd.read_csv

# %%
csv_path = os.path.join('example_datasets', 'MessySuperStoreData.csv')
df = pd.read_csv(csv_path)

# %% [markdown]
# <a id='explore'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background: #e6f2ff">
# <h2> Explore the dataset </h2>
#
# These topics will be covered in some detail in the following sections
#
# **basic data viewing**
#
# show data within the dataframe as well as the column names
#
# * <a href='#df'>view dataframe "preview"</a>
# * <a href='#.head()'> view rows from beginning or end of dataframe (df.head, df.tail)</a>
# * <a href='#shape'>get dataframe shape and length(len, np.shape)</a>
# * <a href='#.columns'>list all columns(.columns)</a>
# * <a href='#column selection'>view only specific columns</a>
# * <a href='#dtypes'>get column data types(.dtypes)</a>
# * <a href='#unique'> unique column entries (.unique)</a>
#
#
#
# **descriptive statistics**
# * <a href='#describe'> get table level descriptive statistics(.describe())(.unique)</a>

# %% [markdown]
# <a id='df'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **view the dataframe**
#
# simply calling the dataframe ('df' or whatever you've named the dataframe) gives a preview view of the dataframe/table
# * shows the first 5 and last 5 rows of data
# * shows the first 10 and last 10 columns of data

# %%
df
# Out:
#          Category      Country Customer ID     Customer Name  Discount  \
# 0       Furniture  Afghanistan    AA-10375      Allen Armold       0.0
# 1       Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0
# 2       Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0
# 3       Furniture  Afghanistan    GM-14455      Gary Mitchum       0.0
# 4       Furniture  Afghanistan    VB-21745  Victoria Brennan       0.0
# ...           ...          ...         ...               ...       ...
# 17526  Technology       Zambia    TS-11205       Thomas Seio       0.0
# 17527  Technology     Zimbabwe     BS-1380      Bill Stewart       0.7
# 17528  Technology     Zimbabwe     JB-6045     Julia Barnett       0.7
# 17529  Technology     Zimbabwe     JC-5775      John Castell       0.7
# 17530  Technology     Zimbabwe     NG-8430     Nathan Gelder       0.7
#
#        Market       Order ID Order Priority  Postal Code        Product ID  \
# 0        APAC  IN-2014-75456           High      11123.0   FUR-FU-10004064
# 1        APAC  IN-2014-29767         Medium          NaN   FUR-BO-10001255
# 2        APAC  IN-2014-29767         Medium          NaN   FUR-FU-10004064
# 3        APAC  IN-2014-20415         Medium          NaN   FUR-BO-10002204
# 4        APAC  IN-2014-47337           High          NaN   FUR-CH-10003965
# ...       ...            ...            ...          ...               ...
# 17526  Africa   ZA-2014-9750         Medium          NaN  TEC-MEM-10002202
# 17527  Africa   ZI-2014-7610         Medium          NaN  TEC-STA-10000699
# 17528  Africa   ZI-2014-5970           High          NaN  TEC-BEL-10003985
# 17529  Africa   ZI-2014-9550         Medium          NaN  TEC-KON-10003116
# 17530  Africa   ZI-2014-3570         Medium          NaN  TEC-OKI-10001433
#
#        ... 11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014  \
# 0      ...       NaN       NaN       NaN       NaN       NaN      NaN
# 1      ...       NaN       NaN       NaN       NaN       NaN      NaN
# 2      ...       NaN       NaN       NaN       NaN       NaN      NaN
# 3      ...       NaN       NaN       NaN       NaN   2070.15      NaN
# 4      ...       NaN       NaN       NaN    914.34       NaN      NaN
# ...    ...       ...       ...       ...       ...       ...      ...
# 17526  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17527  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17528  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17529  ...       NaN       NaN       NaN     71.64       NaN      NaN
# 17530  ...    14.832       NaN       NaN       NaN       NaN      NaN
#
#       3/1/2014  4/1/2014 2/1/2014 6/1/2014
# 0          NaN       NaN      NaN      NaN
# 1      731.820       NaN      NaN      NaN
# 2      169.680       NaN      NaN      NaN
# 3          NaN       NaN      NaN      NaN
# 4          NaN       NaN      NaN      NaN
# ...        ...       ...      ...      ...
# 17526      NaN       NaN   246.42      NaN
# 17527   21.501       NaN      NaN      NaN
# 17528      NaN       NaN      NaN   77.688
# 17529      NaN       NaN      NaN      NaN
# 17530      NaN       NaN      NaN      NaN
#
# [17531 rows x 33 columns]

# %% [markdown]
# <a id='.head()'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **[.head()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) & [.tail()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)**
#
# shows the first or last n rows of data within the dataframe
#
# * by default shows the 5 rows of data
# * adding a number (n) allows the selection of a specific number of rows
# * <code>df.head()</code> shows rows from the beginning of the dataframe,  <code>df.tail()</code> shows rows from the end of the dataframe

# %%
# show the first 8 rows
df.head(8)
# Out:
#     Category      Country Customer ID     Customer Name  Discount  Market  \
# 0  Furniture  Afghanistan    AA-10375      Allen Armold       0.0    APAC
# 1  Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0    APAC
# 2  Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0    APAC
# 3  Furniture  Afghanistan    GM-14455      Gary Mitchum       0.0    APAC
# 4  Furniture  Afghanistan    VB-21745  Victoria Brennan       0.0    APAC
# 5  Furniture      Algeria     CL-2565       Clay Ludtke       0.0  Africa
# 6  Furniture      Algeria     CL-2565       Clay Ludtke       0.0  Africa
# 7  Furniture      Algeria     CR-2730      Craig Reiter       0.0  Africa
#
#         Order ID Order Priority  Postal Code        Product ID  ... 11/1/2014  \
# 0  IN-2014-75456           High      11123.0   FUR-FU-10004064  ...       NaN
# 1  IN-2014-29767         Medium          NaN   FUR-BO-10001255  ...       NaN
# 2  IN-2014-29767         Medium          NaN   FUR-FU-10004064  ...       NaN
# 3  IN-2014-20415         Medium          NaN   FUR-BO-10002204  ...       NaN
# 4  IN-2014-47337           High          NaN   FUR-CH-10003965  ...       NaN
# 5   AG-2014-2760           High          NaN  FUR-DEF-10002865  ...       NaN
# 6   AG-2014-2760           High      41244.0  FUR-NOV-10002453  ...       NaN
# 7   AG-2014-2040           High          NaN  FUR-RUB-10003004  ...       NaN
#
#    9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014 3/1/2014  4/1/2014  \
# 0       NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 1       NaN       NaN       NaN       NaN      NaN   731.82       NaN
# 2       NaN       NaN       NaN       NaN      NaN   169.68       NaN
# 3       NaN       NaN       NaN   2070.15      NaN      NaN       NaN
# 4       NaN       NaN    914.34       NaN      NaN      NaN       NaN
# 5       NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 6       NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 7       NaN    106.92       NaN       NaN      NaN      NaN       NaN
#
#   2/1/2014 6/1/2014
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# 5      NaN    17.61
# 6      NaN   516.00
# 7      NaN      NaN
#
# [8 rows x 33 columns]

# %%
# show the last 7 rows
df.tail(7)
# Out:
#          Category   Country Customer ID  Customer Name  Discount  Market  \
# 17524  Technology    Zambia    SW-10350     Sean Wendt       0.0  Africa
# 17525  Technology    Zambia    SW-10350     Sean Wendt       0.0  Africa
# 17526  Technology    Zambia    TS-11205    Thomas Seio       0.0  Africa
# 17527  Technology  Zimbabwe     BS-1380   Bill Stewart       0.7  Africa
# 17528  Technology  Zimbabwe     JB-6045  Julia Barnett       0.7  Africa
# 17529  Technology  Zimbabwe     JC-5775   John Castell       0.7  Africa
# 17530  Technology  Zimbabwe     NG-8430  Nathan Gelder       0.7  Africa
#
#            Order ID Order Priority  Postal Code        Product ID  ...  \
# 17524  ZA-2014-6660         Medium          NaN  TEC-BRO-10003401  ...
# 17525  ZA-2014-6660         Medium          NaN  TEC-HEW-10002304  ...
# 17526  ZA-2014-9750         Medium          NaN  TEC-MEM-10002202  ...
# 17527  ZI-2014-7610         Medium          NaN  TEC-STA-10000699  ...
# 17528  ZI-2014-5970           High          NaN  TEC-BEL-10003985  ...
# 17529  ZI-2014-9550         Medium          NaN  TEC-KON-10003116  ...
# 17530  ZI-2014-3570         Medium          NaN  TEC-OKI-10001433  ...
#
#       11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014 3/1/2014  \
# 17524       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 17525       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 17526       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 17527       NaN       NaN       NaN       NaN       NaN      NaN   21.501
# 17528       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 17529       NaN       NaN       NaN     71.64       NaN      NaN      NaN
# 17530    14.832       NaN       NaN       NaN       NaN      NaN      NaN
#
#        4/1/2014 2/1/2014 6/1/2014
# 17524       NaN   189.69      NaN
# 17525       NaN   318.12      NaN
# 17526       NaN   246.42      NaN
# 17527       NaN      NaN      NaN
# 17528       NaN      NaN   77.688
# 17529       NaN      NaN      NaN
# 17530       NaN      NaN      NaN
#
# [7 rows x 33 columns]

# %% [markdown]
# <a id='.columns'></a>

# %% [markdown]
# <a id='shape'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Get the shape and length of the dataframe**
# many familiar functions/methods work with DataFrames
#
# * [numpys shape function](https://numpy.org/doc/stable/reference/generated/numpy.shape.html) can give the dimensions of a dataframe
#     * <code>np.shape(df)</code> - returns (rows, columns)
# * [len()](https://docs.python.org/3/library/functions.html#len) - the built in python function will return the number of rows in a dataframe
#     * <code>len(df)</code>

# %%
np.shape(df)
# Out:
# (17531, 33)

# %%
len(df)
# Out:
# 17531

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **[view columns with .columns](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html)**
#
# provides a list of the column lables for a dataframe

# %%
df.columns
# Out:
# Index(['Category', 'Country', 'Customer ID', 'Customer Name', 'Discount',
#        'Market', 'Order ID', 'Order Priority', 'Postal Code', 'Product ID',
#        'Product Name', 'Profit', 'Quantity', 'Region', 'Row ID', 'Segment',
#        'Ship Mode', 'Shipping Cost', 'City, State', 'Sub-Category',
#        'Category (OLD)', '10/1/2014', '7/1/2014', '11/1/2014', '9/1/2014',
#        '1/1/2014', '12/1/2014', '8/1/2014', '5/1/2014', '3/1/2014', '4/1/2014',
#        '2/1/2014', '6/1/2014'],
#       dtype='object')

# %% [markdown]
# <a id='dtypes'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Data Types**
#
# * [.dtypes](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html) provides the datatypes of all columns of a dataframe
#
# * The python built in [type()](https://docs.python.org/3/library/functions.html#type) function also works to get the type for a specific column and row. This can be helpful if the .dtypes function returns "object", use the format: <code>type(df.['column'][index])</code>

# %%
df.dtypes
# Out:
# Category           object
# Country            object
# Customer ID        object
# Customer Name      object
# Discount          float64
# Market             object
# Order ID           object
# Order Priority     object
# Postal Code       float64
# Product ID         object
# Product Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row ID              int64
# Segment            object
# Ship Mode          object
# Shipping Cost     float64
# City, State        object
# Sub-Category       object
# Category (OLD)    float64
# 10/1/2014         float64
# 7/1/2014          float64
# 11/1/2014         float64
# 9/1/2014          float64
# 1/1/2014          float64
# 12/1/2014         float64
# 8/1/2014          float64
# 5/1/2014          float64
# 3/1/2014          float64
# 4/1/2014          float64
# 2/1/2014          float64
# 6/1/2014          float64
# dtype: object

# %% [markdown]
# <a id='column selection'></a>

# %% [markdown]
# <a id='unique'></a>

# %%
# use the built in type() function to get the first row of the "Category" column
type(df["Category"][0])
# Out:
# str

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **[column selection](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#how-do-i-select-specific-columns-from-a-dataframe)**
#
# <img src="example_images/pandas_select_columns.png">
#
# to view a single single column
# * <code>df['column_name']</code>    (returns a pandas series)
#
# ~ OR ~
# * <code>df[['column_name']]</code>     (returns a dataframe)
#
# multiple columns:
# * <code>df[['column_1', 'columns_2']]</code>

# %%
# get the Category column as a pd.series

df["Category"]
# Out:
# 0         Furniture
# 1         Furniture
# 2         Furniture
# 3         Furniture
# 4         Furniture
#             ...
# 17526    Technology
# 17527    Technology
# 17528    Technology
# 17529    Technology
# 17530    Technology
# Name: Category, Length: 17531, dtype: object

# %%
# get the Category and Order ID columns 

df[["Category", "Order ID"]]
# Out:
#          Category       Order ID
# 0       Furniture  IN-2014-75456
# 1       Furniture  IN-2014-29767
# 2       Furniture  IN-2014-29767
# 3       Furniture  IN-2014-20415
# 4       Furniture  IN-2014-47337
# ...           ...            ...
# 17526  Technology   ZA-2014-9750
# 17527  Technology   ZI-2014-7610
# 17528  Technology   ZI-2014-5970
# 17529  Technology   ZI-2014-9550
# 17530  Technology   ZI-2014-3570
#
# [17531 rows x 2 columns]

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **unique entries for a column using [.unique](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#how-do-i-select-specific-columns-from-a-dataframe)**
#
#
# <code>df['column_name'].unique()</code>   returns an array of all unique entries

# %%
# get all unique entries for the Country column

df['Country'].unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Angola', 'Argentina', 'Australia',
#        'Austria', 'Azerbaijan', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Bolivia', 'Brazil', 'Bulgaria', 'Cambodia', 'Cameroon',
#        'Canada', 'Chile', 'China', 'Colombia', "Cote d'Ivoire", 'Croatia',
#        'Cuba', 'Czech Republic', 'Democratic Republic of the Congo',
#        'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Estonia', 'Finland', 'France', 'Gabon', 'Georgia', 'Germany',
#        'Ghana', 'Guatemala', 'Haiti', 'Honduras', 'Hungary', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kyrgyzstan',
#        'Lebanon', 'Liberia', 'Libya', 'Lithuania', 'Macedonia',
#        'Madagascar', 'Malaysia', 'Mali', 'Martinique', 'Mexico',
#        'Moldova', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique',
#        'Myanmar (Burma)', 'Nepal', 'Netherlands', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'Norway', 'Pakistan', 'Panama',
#        'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal',
#        'Republic of the Congo', 'Romania', 'Russia', 'Rwanda',
#        'Saudi Arabia', 'Senegal', 'Singapore', 'Slovenia', 'Somalia',
#        'South Africa', 'South Korea', 'Spain', 'Sudan', 'Sweden',
#        'Switzerland', 'Syria', 'Tanzania', 'Thailand', 'Togo', 'Tunisia',
#        'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam',
#        'Yemen', 'Zambia', 'Zimbabwe', 'Albania', 'Benin',
#        'Bosnia and Herzegovina', 'Central African Republic', 'Ethiopia',
#        'Guinea', 'Guinea-Bissau', 'Hong Kong', 'Mauritania', 'Namibia',
#        'Papua New Guinea', 'Qatar', 'Sierra Leone', 'Slovakia',
#        'Sri Lanka', 'Taiwan', 'Tajikistan', 'Trinidad and Tobago',
#        'United Arab Emirates', 'South Sudan', 'Swaziland'], dtype=object)

# %% [markdown]
# <a id='.iloc'></a>

# %% [markdown]
# <a id='describe'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **get descriptive statistics for quanititative columns with [.describe()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)**
#
# Descriptive statistic are summary statistics that quantitatively describes or summarizes features from a collection of information or dataset. This typically included things like sample size, measures of central tendency (mean, median, mode), measures of variability or dispersion (standard deviation, min, max, kurtosis, skewness)
#
# <img src="example_images/pandas_describe.png">
#
# For each quantitative column the following descriptive statitsics are provided:
# * count
# * mean
# * standard deviation
# * minimum
# * 25, 50 & 75th percentiles
# * max

# %%
df.describe()
# Out:
#            Discount   Postal Code        Profit      Quantity        Row ID  \
# count  17531.000000   3321.000000  17531.000000  17531.000000  17531.000000
# mean       0.143291  56192.587775     28.758540      3.457989  25933.970966
# std        0.211830  31977.397359    174.283412      2.290856  14733.584100
# min        0.000000   1841.000000  -3839.990400      1.000000      1.000000
# 25%        0.000000  28110.000000      0.000000      2.000000  13169.500000
# 50%        0.000000  60440.000000      9.200000      3.000000  25826.000000
# 75%        0.200000  90032.000000     36.808500      5.000000  38803.500000
# max        0.800000  99301.000000   6719.980800     14.000000  51284.000000
#
#        Shipping Cost  Category (OLD)     10/1/2014     7/1/2014     11/1/2014  \
# count   17531.000000             0.0   1626.000000  1087.000000   2147.000000
# mean       26.268085             NaN    260.004077   237.999706    258.630194
# std        56.545260             NaN    543.523703   433.300176    520.039000
# min         0.010000             NaN      0.990000     1.080000      1.197000
# 25%         2.570000             NaN     31.491000    27.225000     30.840000
# 50%         7.720000             NaN     87.940000    78.327000     90.936000
# 75%        24.455000             NaN    267.678000   244.147500    269.190000
# max       867.690000             NaN  11199.968000  4001.040000  10499.970000
#
#           9/1/2014     1/1/2014    12/1/2014     8/1/2014     5/1/2014  \
# count  2018.000000   918.000000  2153.000000  1675.000000  1284.000000
# mean    238.432727   262.819777   233.694238   272.608921   224.611407
# std     463.761215   528.201441   432.184769   502.542821   396.292046
# min       1.359000     2.040000     1.161000     1.584000     1.188000
# 25%      26.793000    27.412500    30.360000    36.984000    30.105000
# 50%      79.620000    83.912400    79.120000    99.870000    79.425000
# 75%     244.085000   263.491500   232.880000   284.043000   226.730000
# max    7958.580000  5443.960000  4864.320000  5211.120000  4298.850000
#
#            3/1/2014     4/1/2014     2/1/2014     6/1/2014
# count   1068.000000  1051.000000   756.000000  1748.000000
# mean     246.349038   230.991305   244.493857   229.870745
# std      593.698325   442.449941   399.022820   423.420032
# min        0.556000     1.188000     1.788000     0.444000
# 25%       32.202000    28.545000    35.460000    29.467500
# 50%       83.788800    79.140000    93.765000    79.960000
# 75%      246.533625   234.338000   275.121000   239.477925
# max    13999.960000  4799.984000  3425.400000  5486.670000

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **STUDENT EXERCISES:**

# %% [markdown]
# <a id='dataselection'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background: #e6f2ff">
# <h2> Data Selection </h2>
#
#
# **basic data selection**
# * <a href='#getvalues'>get all values for a specific column (.values)</a>
# * <a href='#iloc'>select data by integer Index/position</a>
# * <a href='#loc'>select data by labels/names</a>
#
#
# **advanced data selection**
# * <a href='#conditionalselection'>select data for a given condition or threshold</a>
# * <a href='#conditionalselectionandreturn'>return subset of data for a given condition or threshold</a>
# * <a href='#multicondition'>select data based on multiple conditions or thresholds</a>
# * <a href='#multioptionlist'> multiple condition options using a list</a>

# %% [markdown]
# <a id='getvalues'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **selecting specific values**
#
# * to get the values of a specific column in an array use[.values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.values.html)
#     * NaNs will be maintained
# * to get turn the whole dataframe into an array use [.to_numpy](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_numpy.html#pandas.DataFrame.to_numpy)

# %%
# use .values to get the values of the "Postal Code" column
df["Postal Code"].values
# Out:
# array([11123.,    nan,    nan, ...,    nan,    nan,    nan])

# %%
# use .to_numpy to get the dataframe as a numpy array
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of          Category      Country Customer ID     Customer Name  Discount  \
# 0       Furniture  Afghanistan    AA-10375      Allen Armold       0.0
# 1       Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0
# 2       Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0
# 3       Furniture  Afghanistan    GM-14455      Gary Mitchum       0.0
# 4       Furniture  Afghanistan    VB-21745  Victoria Brennan       0.0
# ...           ...          ...         ...               ...       ...
# 17526  Technology       Zambia    TS-11205       Thomas Seio       0.0
# 17527  Technology     Zimbabwe     BS-1380      Bill Stewart       0.7
# 17528  Technology     Zimbabwe     JB-6045     Julia Barnett       0.7
# 17529  Technology     Zimbabwe     JC-5775      John Castell       0.7
# 17530  Technology     Zimbabwe     NG-8430     Nathan Gelder       0.7
#
#        Market       Order ID Order Priority  Postal Code        Product ID  \
# 0        APAC  IN-2014-75456           High      11123.0   FUR-FU-10004064
# 1        APAC  IN-2014-29767         Medium          NaN   FUR-BO-10001255
# 2        APAC  IN-2014-29767         Medium          NaN   FUR-FU-10004064
# 3        APAC  IN-2014-20415         Medium          NaN   FUR-BO-10002204
# 4        APAC  IN-2014-47337           High          NaN   FUR-CH-10003965
# ...       ...            ...            ...          ...               ...
# 17526  Africa   ZA-2014-9750         Medium          NaN  TEC-MEM-10002202
# 17527  Africa   ZI-2014-7610         Medium          NaN  TEC-STA-10000699
# 17528  Africa   ZI-2014-5970           High          NaN  TEC-BEL-10003985
# 17529  Africa   ZI-2014-9550         Medium          NaN  TEC-KON-10003116
# 17530  Africa   ZI-2014-3570         Medium          NaN  TEC-OKI-10001433
#
#        ... 11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014  \
# 0      ...       NaN       NaN       NaN       NaN       NaN      NaN
# 1      ...       NaN       NaN       NaN       NaN       NaN      NaN
# 2      ...       NaN       NaN       NaN       NaN       NaN      NaN
# 3      ...       NaN       NaN       NaN       NaN   2070.15      NaN
# 4      ...       NaN       NaN       NaN    914.34       NaN      NaN
# ...    ...       ...       ...       ...       ...       ...      ...
# 17526  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17527  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17528  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17529  ...       NaN       NaN       NaN     71.64       NaN      NaN
# 17530  ...    14.832       NaN       NaN       NaN       NaN      NaN
#
#       3/1/2014  4/1/2014 2/1/2014 6/1/2014
# 0          NaN       NaN      NaN      NaN
# 1      731.820       NaN      NaN      NaN
# 2      169.680       NaN      NaN      NaN
# 3          NaN       NaN      NaN      NaN
# 4          NaN       NaN      NaN      NaN
# ...        ...       ...      ...      ...
# 17526      NaN       NaN   246.42      NaN
# 17527   21.501       NaN      NaN      NaN
# 17528      NaN       NaN      NaN   77.688
# 17529      NaN       NaN      NaN      NaN
# 17530      NaN       NaN      NaN      NaN
#
# [17531 rows x 33 columns]>

# %% [markdown]
# <a id='iloc'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Select rows or columns by index**
#
# [iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html) allows for selections of specific indices of rows and columns
#
# Example: <code>df.iloc([rows,columns])</code>
#
# General selection info:
# * the function df.iloc[:,:] would select all rows and all columns
# * [0:4, :] would select rows 0-4 (first 5 rows) and all columns
# * use negative numbers to start selection at end of dataframe
#     * .iloc[:,-5:] would select the last 5 columns

# %%
# get the first 9 rows and all columns
df.iloc[:9,:]
# Out:
#     Category      Country Customer ID     Customer Name  Discount  Market  \
# 0  Furniture  Afghanistan    AA-10375      Allen Armold       0.0    APAC
# 1  Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0    APAC
# 2  Furniture  Afghanistan    CA-12055   Cathy Armstrong       0.0    APAC
# 3  Furniture  Afghanistan    GM-14455      Gary Mitchum       0.0    APAC
# 4  Furniture  Afghanistan    VB-21745  Victoria Brennan       0.0    APAC
# 5  Furniture      Algeria     CL-2565       Clay Ludtke       0.0  Africa
# 6  Furniture      Algeria     CL-2565       Clay Ludtke       0.0  Africa
# 7  Furniture      Algeria     CR-2730      Craig Reiter       0.0  Africa
# 8  Furniture      Algeria     DR-2940     Daniel Raglin       0.0  Africa
#
#         Order ID Order Priority  Postal Code        Product ID  ... 11/1/2014  \
# 0  IN-2014-75456           High      11123.0   FUR-FU-10004064  ...       NaN
# 1  IN-2014-29767         Medium          NaN   FUR-BO-10001255  ...       NaN
# 2  IN-2014-29767         Medium          NaN   FUR-FU-10004064  ...       NaN
# 3  IN-2014-20415         Medium          NaN   FUR-BO-10002204  ...       NaN
# 4  IN-2014-47337           High          NaN   FUR-CH-10003965  ...       NaN
# 5   AG-2014-2760           High          NaN  FUR-DEF-10002865  ...       NaN
# 6   AG-2014-2760           High      41244.0  FUR-NOV-10002453  ...       NaN
# 7   AG-2014-2040           High          NaN  FUR-RUB-10003004  ...       NaN
# 8   AG-2014-2600         Medium          NaN  FUR-IKE-10003642  ...    287.58
#
#    9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014 3/1/2014  4/1/2014  \
# 0       NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 1       NaN       NaN       NaN       NaN      NaN   731.82       NaN
# 2       NaN       NaN       NaN       NaN      NaN   169.68       NaN
# 3       NaN       NaN       NaN   2070.15      NaN      NaN       NaN
# 4       NaN       NaN    914.34       NaN      NaN      NaN       NaN
# 5       NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 6       NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 7       NaN    106.92       NaN       NaN      NaN      NaN       NaN
# 8       NaN       NaN       NaN       NaN      NaN      NaN       NaN
#
#   2/1/2014 6/1/2014
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# 5      NaN    17.61
# 6      NaN   516.00
# 7      NaN      NaN
# 8      NaN      NaN
#
# [9 rows x 33 columns]

# %%
# get all rows and last 4 columns 
df.iloc[:,-4:]
# Out:
#        3/1/2014  4/1/2014  2/1/2014  6/1/2014
# 0           NaN       NaN       NaN       NaN
# 1       731.820       NaN       NaN       NaN
# 2       169.680       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...
# 17526       NaN       NaN    246.42       NaN
# 17527    21.501       NaN       NaN       NaN
# 17528       NaN       NaN       NaN    77.688
# 17529       NaN       NaN       NaN       NaN
# 17530       NaN       NaN       NaN       NaN
#
# [17531 rows x 4 columns]

# %% [markdown]
# <a id='loc'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **access a group of rows or columns using labels**
#
# [.loc[ ]](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) allows access to a group of rows and columns by label(s) or a boolean array.
#
# select rows:
# * <code>df.loc['row index']</code>
#     * hint: similar to column selection described above, for row selection using df.loc[ ] returns a series where df.loc[[ ]] returns a dataframe
#
# select row and column:
# * <code>df.loc['row index', 'column']</code>

# %%
# get row 17526

df.loc[17526]
# Out:
# Category                   Technology
# Country                        Zambia
# Customer ID                  TS-11205
# Customer Name             Thomas Seio
# Discount                          0.0
# Market                         Africa
# Order ID                 ZA-2014-9750
# Order Priority                 Medium
# Postal Code                       NaN
# Product ID           TEC-MEM-10002202
# Product Name      Memorex Router, USB
# Profit                          19.71
# Quantity                            1
# Region                         Africa
# Row ID                          49187
# Segment                     Corporate
# Ship Mode                Second Class
# Shipping Cost                   20.62
# City, State          Ndola,Copperbelt
# Sub-Category              Accessories
# Category (OLD)                    NaN
# 10/1/2014                         NaN
# 7/1/2014                          NaN
# 11/1/2014                         NaN
# 9/1/2014                          NaN
# 1/1/2014                          NaN
# 12/1/2014                         NaN
# 8/1/2014                          NaN
# 5/1/2014                          NaN
# 3/1/2014                          NaN
# 4/1/2014                          NaN
# 2/1/2014                       246.42
# 6/1/2014                          NaN
# Name: 17526, dtype: object

# %%
# get row 45 and column'Country'

df.loc[45,'Country']
# Out:
# 'Argentina'

# %% [markdown]
# <a id='conditionalselection'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
#
# **Select data given a specific threshold or condition**
#
# You can conditionally select data using [.loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) or [.query()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html)
#
# examples using .loc:
# * <code>df.loc[df['column'] > 7]</code>
# * <code>df.loc[df['column'] == 'string']</code>
#
# .query() queries the columns of a DataFrame with a boolean expression. Examples using .query:
# * <code>df.query('column > 7')</code>
# * <code>df.query('column == string')</code>

# %%
# use .loc[] to select where the Country is Senegal

df.loc[df["Country"]=="Senegal"]
# Out:
#               Category  Country Customer ID       Customer Name  Discount  \
# 2252         Furniture  Senegal      AJ-945       Ashley Jarboe       0.0
# 2253         Furniture  Senegal      AJ-945       Ashley Jarboe       0.0
# 2254         Furniture  Senegal     JE-5715          Joe Elijah       0.0
# 2255         Furniture  Senegal     JM-5655         Jim Mitchum       0.0
# 10443  Office Supplies  Senegal      AG-495     Andrew Gjertsen       0.0
# 10444  Office Supplies  Senegal      AJ-945       Ashley Jarboe       0.0
# 10445  Office Supplies  Senegal      AW-930     Arthur Wiediger       0.0
# 10446  Office Supplies  Senegal     BC-1125       Becky Castell       0.0
# 10447  Office Supplies  Senegal     BE-1410         Bobby Elias       0.0
# 10448  Office Supplies  Senegal     BP-1050          Barry Pond       0.0
# 10449  Office Supplies  Senegal     BT-1440       Bobby Trafton       0.0
# 10450  Office Supplies  Senegal     FG-4260     Frank Gastineau       0.0
# 10451  Office Supplies  Senegal     GM-4500        Gene McClure       0.0
# 10452  Office Supplies  Senegal     JW-5220           Jane Waco       0.0
# 10453  Office Supplies  Senegal     JW-5220           Jane Waco       0.0
# 10454  Office Supplies  Senegal     LB-6795      Laurel Beltran       0.0
# 10455  Office Supplies  Senegal     LB-6795      Laurel Beltran       0.0
# 10456  Office Supplies  Senegal     ME-7725           Max Engle       0.0
# 10457  Office Supplies  Senegal     MM-7920       Michael Moore       0.0
# 10458  Office Supplies  Senegal     NC-8340         Nat Carroll       0.0
# 10459  Office Supplies  Senegal     QJ-9255        Quincy Jones       0.0
# 10460  Office Supplies  Senegal     QJ-9255        Quincy Jones       0.0
# 10461  Office Supplies  Senegal     QJ-9255        Quincy Jones       0.0
# 10462  Office Supplies  Senegal     QJ-9255        Quincy Jones       0.0
# 10463  Office Supplies  Senegal    ZD-11925  Zuschuss Donatelli       0.0
# 10464  Office Supplies  Senegal    ZD-11925  Zuschuss Donatelli       0.0
# 10465  Office Supplies  Senegal    ZD-11925  Zuschuss Donatelli       0.0
# 10466  Office Supplies  Senegal    ZD-11925  Zuschuss Donatelli       0.0
# 10467  Office Supplies  Senegal    ZD-11925  Zuschuss Donatelli       0.0
# 16399       Technology  Senegal      AJ-945       Ashley Jarboe       0.0
# 16400       Technology  Senegal      AJ-945       Ashley Jarboe       0.0
# 16401       Technology  Senegal      AJ-945       Ashley Jarboe       0.0
# 16402       Technology  Senegal     BE-1410         Bobby Elias       0.0
# 16403       Technology  Senegal     BE-1410         Bobby Elias       0.0
# 16404       Technology  Senegal     GH-4425          Gary Hwang       0.0
# 16405       Technology  Senegal     GH-4425          Gary Hwang       0.0
# 16406       Technology  Senegal     JH-6180        Justin Hirsh       0.0
# 16407       Technology  Senegal     JH-6180        Justin Hirsh       0.0
# 16408       Technology  Senegal     JM-5655         Jim Mitchum       0.0
# 16409       Technology  Senegal     JW-5220           Jane Waco       0.0
# 16410       Technology  Senegal     RD-9930   Russell D'Ascenzo       0.0
# 16411       Technology  Senegal    TS-11655       Trudy Schmidt       0.0
#
#        Market      Order ID Order Priority  Postal Code        Product ID  \
# 2252   Africa  SG-2014-9750         Medium          NaN  FUR-BEV-10002803
# 2253   Africa  SG-2014-9750         Medium          NaN  FUR-RUB-10001094
# 2254   Africa  SG-2014-8030         Medium          NaN  FUR-RUB-10002817
# 2255   Africa  SG-2014-1600           High          NaN  FUR-HON-10001776
# 10443  Africa  SG-2014-4800         Medium          NaN  OFF-AVE-10002102
# 10444  Africa  SG-2014-9750         Medium          NaN  OFF-BIN-10002236
# 10445  Africa  SG-2014-5470         Medium          NaN  OFF-GLO-10001348
# 10446  Africa  SG-2014-1770           High          NaN  OFF-CAR-10001911
# 10447  Africa  SG-2014-5940         Medium          NaN  OFF-SAN-10003368
# 10448  Africa  SG-2014-7320         Medium          NaN  OFF-TEN-10000894
# 10449  Africa  SG-2014-3940           High          NaN  OFF-ENE-10001906
# 10450  Africa  SG-2014-2120           High          NaN  OFF-ENE-10003274
# 10451  Africa  SG-2014-2890           High          NaN  OFF-XER-10004012
# 10452  Africa  SG-2014-9460         Medium          NaN  OFF-BIN-10002061
# 10453  Africa  SG-2014-9460         Medium          NaN  OFF-FIS-10001591
# 10454  Africa   SG-2014-360         Medium          NaN  OFF-BOS-10002705
# 10455  Africa   SG-2014-360         Medium          NaN  OFF-IBI-10001494
# 10456  Africa  SG-2014-1610         Medium          NaN  OFF-ACM-10002301
# 10457  Africa  SG-2014-9800       Critical          NaN  OFF-NOV-10000092
# 10458  Africa   SG-2014-720           High          NaN  OFF-TEN-10001480
# 10459  Africa  SG-2014-2090            Low          NaN  OFF-ACC-10003422
# 10460  Africa  SG-2014-2090            Low          NaN  OFF-ADV-10002549
# 10461  Africa  SG-2014-2090            Low          NaN  OFF-GRE-10002561
# 10462  Africa  SG-2014-2090            Low          NaN  OFF-STO-10002042
# 10463  Africa  SG-2014-5870           High          NaN  OFF-CAR-10001577
# 10464  Africa  SG-2014-5870           High          NaN  OFF-IBI-10001772
# 10465  Africa  SG-2014-5870           High          NaN  OFF-STA-10003756
# 10466  Africa  SG-2014-5870           High          NaN  OFF-STA-10003756
# 10467  Africa  SG-2014-5870           High          NaN  OFF-STA-10003803
# 16399  Africa  SG-2014-9750         Medium          NaN  TEC-CAN-10002802
# 16400  Africa  SG-2014-9750         Medium          NaN  TEC-SAN-10000235
# 16401  Africa  SG-2014-9750         Medium          NaN  TEC-SHA-10000052
# 16402  Africa  SG-2014-5940         Medium          NaN  TEC-BRO-10000773
# 16403  Africa  SG-2014-5940         Medium          NaN  TEC-HEW-10000930
# 16404  Africa  SG-2014-4440       Critical          NaN  TEC-BEL-10003177
# 16405  Africa  SG-2014-4440       Critical          NaN  TEC-ENE-10002686
# 16406  Africa  SG-2014-8980           High          NaN  TEC-HP -10004149
# 16407  Africa  SG-2014-8980           High          NaN  TEC-SHA-10001309
# 16408  Africa  SG-2014-1600           High          NaN  TEC-NOK-10001172
# 16409  Africa  SG-2014-9460         Medium          NaN  TEC-CIS-10002259
# 16410  Africa  SG-2014-2730           High          NaN  TEC-BRO-10004178
# 16411  Africa  SG-2014-3780         Medium          NaN  TEC-MOT-10001196
#
#        ... 11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014  \
# 2252   ...       NaN    925.23       NaN       NaN       NaN      NaN
# 2253   ...       NaN     87.72       NaN       NaN       NaN      NaN
# 2254   ...       NaN       NaN       NaN       NaN       NaN      NaN
# 2255   ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10443  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10444  ...       NaN    215.52       NaN       NaN       NaN      NaN
# 10445  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10446  ...       NaN       NaN       NaN     11.46       NaN      NaN
# 10447  ...       NaN       NaN       NaN     44.40       NaN      NaN
# 10448  ...       NaN       NaN       NaN       NaN       NaN    186.0
# 10449  ...       NaN     22.41       NaN       NaN       NaN      NaN
# 10450  ...       NaN     39.60       NaN       NaN       NaN      NaN
# 10451  ...       NaN       NaN       NaN       NaN    105.48      NaN
# 10452  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10453  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10454  ...       NaN     20.13       NaN       NaN       NaN      NaN
# 10455  ...       NaN     18.54       NaN       NaN       NaN      NaN
# 10456  ...       NaN       NaN       NaN     41.28       NaN      NaN
# 10457  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10458  ...     54.24       NaN       NaN       NaN       NaN      NaN
# 10459  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10460  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10461  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10462  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10463  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10464  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10465  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10466  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 10467  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16399  ...       NaN    142.38       NaN       NaN       NaN      NaN
# 16400  ...       NaN    256.56       NaN       NaN       NaN      NaN
# 16401  ...       NaN   1926.72       NaN       NaN       NaN      NaN
# 16402  ...       NaN       NaN       NaN    141.09       NaN      NaN
# 16403  ...       NaN       NaN       NaN    148.32       NaN      NaN
# 16404  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16405  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16406  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16407  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16408  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16409  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16410  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 16411  ...       NaN       NaN       NaN       NaN       NaN      NaN
#
#       3/1/2014  4/1/2014 2/1/2014 6/1/2014
# 2252       NaN       NaN      NaN      NaN
# 2253       NaN       NaN      NaN      NaN
# 2254       NaN       NaN      NaN      NaN
# 2255       NaN       NaN    90.30      NaN
# 10443      NaN       NaN      NaN    14.04
# 10444      NaN       NaN      NaN      NaN
# 10445      NaN       NaN      NaN      NaN
# 10446      NaN       NaN      NaN      NaN
# 10447      NaN       NaN      NaN      NaN
# 10448      NaN       NaN      NaN      NaN
# 10449      NaN       NaN      NaN      NaN
# 10450      NaN       NaN      NaN      NaN
# 10451      NaN       NaN      NaN      NaN
# 10452      NaN     46.32      NaN      NaN
# 10453      NaN    169.20      NaN      NaN
# 10454      NaN       NaN      NaN      NaN
# 10455      NaN       NaN      NaN      NaN
# 10456      NaN       NaN      NaN      NaN
# 10457      NaN       NaN      NaN      NaN
# 10458      NaN       NaN      NaN      NaN
# 10459      NaN       NaN    16.65      NaN
# 10460      NaN       NaN    28.08      NaN
# 10461      NaN       NaN    95.16      NaN
# 10462      NaN       NaN    10.53      NaN
# 10463      NaN       NaN      NaN   199.08
# 10464      NaN       NaN      NaN    33.48
# 10465      NaN       NaN      NaN    88.86
# 10466      NaN       NaN      NaN   266.58
# 10467      NaN       NaN      NaN   127.68
# 16399      NaN       NaN      NaN      NaN
# 16400      NaN       NaN      NaN      NaN
# 16401      NaN       NaN      NaN      NaN
# 16402      NaN       NaN      NaN      NaN
# 16403      NaN       NaN      NaN      NaN
# 16404      NaN       NaN      NaN      NaN
# 16405      NaN       NaN      NaN      NaN
# 16406      NaN       NaN      NaN   483.78
# 16407      NaN       NaN      NaN   295.29
# 16408      NaN       NaN   123.24      NaN
# 16409      NaN   3908.88      NaN      NaN
# 16410      NaN       NaN      NaN   378.81
# 16411      NaN       NaN      NaN   176.22
#
# [42 rows x 33 columns]

# %%
# use .query() to select where Profit > 500

df.query('Profit > 500')
# Out:
#          Category        Country Customer ID     Customer Name  Discount  \
# 3       Furniture    Afghanistan    GM-14455      Gary Mitchum       0.0
# 16      Furniture         Angola     BD-1725  Bruce Degenhardt       0.0
# 94      Furniture      Australia    CM-12235      Chris McAfee       0.1
# 95      Furniture      Australia    CM-12445       Chuck Magee       0.0
# 146     Furniture      Australia    JC-15340   Jasper Cacioppo       0.1
# ...           ...            ...         ...               ...       ...
# 17439  Technology  United States    TA-21385      Tom Ashbrook       0.0
# 17441  Technology  United States    TA-21385      Tom Ashbrook       0.2
# 17442  Technology  United States    TB-21175     Thomas Boland       0.0
# 17472  Technology  United States    TS-21370      Todd Sumrall       0.0
# 17479  Technology  United States    TT-21460     Tonja Turnell       0.0
#
#        Market        Order ID Order Priority  Postal Code        Product ID  \
# 3        APAC   IN-2014-20415         Medium          NaN   FUR-BO-10002204
# 16     Africa    AO-2014-2270            Low          NaN  FUR-CHR-10002278
# 94       APAC   IN-2014-23880         Medium          NaN   FUR-BO-10004852
# 95       APAC   IN-2014-80286           High          NaN   FUR-CH-10000051
# 146      APAC   ID-2014-35892         Medium          NaN   FUR-CH-10003597
# ...       ...             ...            ...          ...               ...
# 17439      US  CA-2014-127180           High      10024.0   TEC-PH-10001494
# 17441      US  CA-2014-127180           High      10024.0   TEC-CO-10004722
# 17442      US  CA-2014-143567       Critical      42420.0   TEC-AC-10004145
# 17472      US  CA-2014-143112         Medium      10035.0   TEC-MA-10001047
# 17479      US  CA-2014-141439         Medium      47374.0   TEC-PH-10002624
#
#        ... 11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014  \
# 3      ...       NaN       NaN       NaN       NaN   2070.15      NaN
# 16     ...       NaN       NaN       NaN       NaN       NaN  1877.16
# 94     ...       NaN       NaN       NaN       NaN       NaN      NaN
# 95     ...  2841.660       NaN       NaN       NaN       NaN      NaN
# 146    ...  2503.872       NaN       NaN       NaN       NaN      NaN
# ...    ...       ...       ...       ...       ...       ...      ...
# 17439  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17441  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17442  ...  2249.910       NaN       NaN       NaN       NaN      NaN
# 17472  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17479  ...  1879.960       NaN       NaN       NaN       NaN      NaN
#
#       3/1/2014  4/1/2014 2/1/2014  6/1/2014
# 3          NaN       NaN      NaN       NaN
# 16         NaN       NaN      NaN       NaN
# 94         NaN       NaN      NaN  3139.128
# 95         NaN       NaN      NaN       NaN
# 146        NaN       NaN      NaN       NaN
# ...        ...       ...      ...       ...
# 17439      NaN       NaN      NaN       NaN
# 17441      NaN       NaN      NaN       NaN
# 17442      NaN       NaN      NaN       NaN
# 17472      NaN       NaN      NaN       NaN
# 17479      NaN       NaN      NaN       NaN
#
# [231 rows x 33 columns]

# %% [markdown]
# <a id='conditionalselectionandreturn'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
#
# **Return a subset of data given a specific threshold or condition**
#
# You can also return specific columns after doing conditional selection data using [.loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html).
#
# single return column:
# * <code>df.loc[df['selection_column'] > 7, 'return_column']</code>
#
# multiple return columns (provide columns as a list):
# * <code>df.loc[df['selection_column'] > 7, ['return_column1', 'return_column2']]</code>

# %%
# get the Category and Sub-Category where profit is above 500

df.loc[df["Profit"] > 500, ["Category", "Sub-Category"]]
# Out:
#          Category Sub-Category
# 3       Furniture    Bookcases
# 16      Furniture       Tables
# 94      Furniture    Bookcases
# 95      Furniture       Chairs
# 146     Furniture       Chairs
# ...           ...          ...
# 17439  Technology       Phones
# 17441  Technology      Copiers
# 17442  Technology  Accessories
# 17472  Technology     Machines
# 17479  Technology       Phones
#
# [231 rows x 2 columns]

# %% [markdown]
# <a id='multicondition'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
#
# **Multiple condition selection**
#
# You may wish to select rows or columns where multiple conditions are met. You can do this with <code>.loc</code>  by using boolean condition statements like <code>and</code> and <code>or</code>. You will need to place <code>( )</code> around each boolean statement.
# * NOTE!: to work with pandas you must replace <code>&</code> for <code>and</code>, and <code>|</code> for <code>or</code>
#
# example:
# <code>df.loc[(df['column1']=='string')&(df['column2'] > threshold)]</code>
#
#
#
# You can also use [<code>.query</code>](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html) to select data for multiple conditions using boolean statments with <code>&</code> and <code>|</code>
#
# example:
# <code>df.query('column1=="String" & column2 <= threshold')</code>

# %%
# return all entries where Profit is greater than 900 and the Sub-Category is "Bookcases"

df.loc[(df['Sub-Category']=="Bookcases")&(df['Profit'] >900)]
# Out:
#        Category         Country Customer ID     Customer Name  Discount  \
# 94    Furniture       Australia    CM-12235      Chris McAfee       0.1
# 178   Furniture       Australia    MB-17305   Maria Bertelson       0.1
# 562   Furniture           China    MG-17695     Maureen Gnade       0.0
# 606   Furniture           China    TS-21505        Tony Sayre       0.0
# 668   Furniture            Cuba    ML-17410      Maris LaWare       0.0
# 1333  Furniture           India    VG-21805       Vivek Grady       0.0
# 2322  Furniture           Spain    DK-13090         Dave Kipp       0.0
# 2579  Furniture  United Kingdom    MS-17770  Maxwell Schwartz       0.0
# 3338  Furniture          Zambia     DB-3615     Doug Bickford       0.0
#
#       Market         Order ID Order Priority  Postal Code        Product ID  \
# 94      APAC    IN-2014-23880         Medium          NaN   FUR-BO-10004852
# 178     APAC    IN-2014-56206         Medium          NaN   FUR-BO-10001471
# 562     APAC    IN-2014-17930         Medium          NaN   FUR-BO-10001471
# 606     APAC    IN-2014-66573           High          NaN   FUR-BO-10004665
# 668    LATAM   MX-2014-157077           High          NaN   FUR-BO-10002300
# 1333    APAC    IN-2014-76016         Medium          NaN   FUR-BO-10004852
# 2322      EU  IT-2014-4540740           High          NaN   FUR-BO-10004999
# 2579      EU  ES-2014-4957212           High          NaN   FUR-BO-10004709
# 3338  Africa     ZA-2014-7540         Medium          NaN  FUR-IKE-10002894
#
#       ... 11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014 3/1/2014  \
# 94    ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 178   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 562   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 606   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 668   ...   1916.88       NaN       NaN       NaN       NaN      NaN      NaN
# 1333  ...       NaN   5667.87       NaN       NaN       NaN      NaN      NaN
# 2322  ...       NaN       NaN       NaN   2188.05       NaN      NaN      NaN
# 2579  ...       NaN   2898.21       NaN       NaN       NaN      NaN      NaN
# 3338  ...       NaN   2180.34       NaN       NaN       NaN      NaN      NaN
#
#       4/1/2014 2/1/2014  6/1/2014
# 94         NaN      NaN  3139.128
# 178        NaN      NaN  5486.670
# 562        NaN      NaN       NaN
# 606        NaN      NaN       NaN
# 668        NaN      NaN       NaN
# 1333       NaN      NaN       NaN
# 2322       NaN      NaN       NaN
# 2579       NaN      NaN       NaN
# 3338       NaN      NaN       NaN
#
# [9 rows x 33 columns]

# %%
# return all entries where the Country is "Australia" or the Country is "Zambia"

df.query('Country=="Australia" | Country=="Zambia"')
# Out:
#          Category    Country Customer ID         Customer Name  Discount  \
# 50      Furniture  Australia    AA-10315            Alex Avila       0.1
# 51      Furniture  Australia    AA-10375          Allen Armold       0.1
# 52      Furniture  Australia    AB-10150           Aimee Bixby       0.1
# 53      Furniture  Australia    AB-10255  Alejandro Ballentine       0.1
# 54      Furniture  Australia    AB-10255  Alejandro Ballentine       0.4
# ...           ...        ...         ...                   ...       ...
# 17522  Technology     Zambia     DD-3570     Dorothy Dickinson       0.0
# 17523  Technology     Zambia     LR-7035             Lisa Ryan       0.0
# 17524  Technology     Zambia    SW-10350            Sean Wendt       0.0
# 17525  Technology     Zambia    SW-10350            Sean Wendt       0.0
# 17526  Technology     Zambia    TS-11205           Thomas Seio       0.0
#
#        Market       Order ID Order Priority  Postal Code        Product ID  \
# 50       APAC  ID-2014-42388           High          NaN   FUR-FU-10004780
# 51       APAC  IN-2014-25644         Medium          NaN   FUR-BO-10004230
# 52       APAC  IN-2014-10090         Medium          NaN   FUR-CH-10001204
# 53       APAC  IN-2014-64396            Low          NaN   FUR-FU-10001129
# 54       APAC  ID-2014-84164         Medium          NaN   FUR-FU-10000507
# ...       ...            ...            ...          ...               ...
# 17522  Africa   ZA-2014-1370         Medium          NaN  TEC-BRO-10003986
# 17523  Africa   ZA-2014-8330           High          NaN  TEC-CIS-10003439
# 17524  Africa   ZA-2014-6660         Medium          NaN  TEC-BRO-10003401
# 17525  Africa   ZA-2014-6660         Medium          NaN  TEC-HEW-10002304
# 17526  Africa   ZA-2014-9750         Medium          NaN  TEC-MEM-10002202
#
#        ... 11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014  \
# 50     ...       NaN       NaN       NaN       NaN     99.09      NaN
# 51     ...       NaN       NaN       NaN    444.42       NaN      NaN
# 52     ...       NaN       NaN       NaN       NaN       NaN      NaN
# 53     ...       NaN       NaN       NaN       NaN       NaN      NaN
# 54     ...       NaN       NaN       NaN       NaN       NaN      NaN
# ...    ...       ...       ...       ...       ...       ...      ...
# 17522  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17523  ...       NaN       NaN       NaN       NaN     88.53      NaN
# 17524  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17525  ...       NaN       NaN       NaN       NaN       NaN      NaN
# 17526  ...       NaN       NaN       NaN       NaN       NaN      NaN
#
#       3/1/2014  4/1/2014 2/1/2014 6/1/2014
# 50         NaN       NaN      NaN      NaN
# 51         NaN       NaN      NaN      NaN
# 52         NaN    88.101      NaN      NaN
# 53         NaN       NaN      NaN    91.26
# 54       31.14       NaN      NaN      NaN
# ...        ...       ...      ...      ...
# 17522      NaN       NaN      NaN      NaN
# 17523      NaN       NaN      NaN      NaN
# 17524      NaN       NaN   189.69      NaN
# 17525      NaN       NaN   318.12      NaN
# 17526      NaN       NaN   246.42      NaN
#
# [1023 rows x 33 columns]

# %% [markdown]
# <a id='multioptionlist'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
#
# **Multiple conditions using a list**
#
# If you have multiple conditions or options for a single column using [.isin](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html) may be particularly helpful.
#
# Using isin lets you define a list values to check for. You can either define this within the .loc statement or outside it if the list is particularly long.
#
# defined inside .loc statement:
#
# <code>subset_df = df.loc[df['column'].isin(['string1','string2'])]</code>
#
# defined outside .loc statement:
#
# <code>values_list = ['string1','string2', 'string3', 'string4']
# subset_df = df.loc[df['column'].isin(values_list)]</code>

# %%
# return the dataframe where the Country is either 
# 'Austria', 'South Korea', 'Uganda', 'Thailand', 'Nicaragua', or 'Slovakia'

countries_list = ['Austria', 'South Korea', 'Uganda', 'Thailand', 'Nicaragua','Slovakia']

df.loc[df['Country'].isin(countries_list)]
# Out:
#          Category   Country Customer ID       Customer Name  Discount  Market  \
# 262     Furniture   Austria    AH-10030       Aaron Hawkins      0.00      EU
# 263     Furniture   Austria    AH-10690       Anna Häberlin      0.00      EU
# 264     Furniture   Austria    DL-13315   Delfina Latchford      0.00      EU
# 265     Furniture   Austria    EB-14110      Eugene Barchas      0.00      EU
# 266     Furniture   Austria     FM-4215       Filia McAdams      0.00    EMEA
# ...           ...       ...         ...                 ...       ...     ...
# 16610  Technology  Thailand    TP-21130    Theone Pippenger      0.37    APAC
# 16611  Technology  Thailand    TP-21130    Theone Pippenger      0.47    APAC
# 16612  Technology  Thailand    VD-21670   Valerie Dominguez      0.37    APAC
# 16708  Technology    Uganda     JC-5340     Jasper Cacioppo      0.70  Africa
# 16709  Technology    Uganda    SU-10665  Stephanie Ulpright      0.70  Africa
#
#               Order ID Order Priority  Postal Code        Product ID  ...  \
# 262    ES-2014-5295631       Critical          NaN   FUR-BO-10001165  ...
# 263    ES-2014-4138832         Medium          NaN   FUR-CH-10002819  ...
# 264    ES-2014-3977309         Medium          NaN   FUR-CH-10004774  ...
# 265    ES-2014-4385660         Medium          NaN   FUR-CH-10004792  ...
# 266       AU-2014-1530         Medium          NaN  FUR-NOV-10004962  ...
# ...                ...            ...          ...               ...  ...
# 16610    ID-2014-44117         Medium          NaN   TEC-CO-10001726  ...
# 16611    ID-2014-44117         Medium          NaN   TEC-AC-10003408  ...
# 16612    ID-2014-33659         Medium          NaN   TEC-CO-10001954  ...
# 16708     UG-2014-8990           High          NaN  TEC-SAM-10001843  ...
# 16709     UG-2014-4850            Low          NaN  TEC-SAM-10004384  ...
#
#       11/1/2014  9/1/2014  1/1/2014 12/1/2014  8/1/2014 5/1/2014 3/1/2014  \
# 262         NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 263         NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 264      3221.4       NaN       NaN       NaN       NaN      NaN      NaN
# 265         NaN    680.76       NaN       NaN       NaN      NaN      NaN
# 266         NaN    193.80       NaN       NaN       NaN      NaN      NaN
# ...         ...       ...       ...       ...       ...      ...      ...
# 16610       NaN       NaN       NaN       NaN  323.3601      NaN      NaN
# 16611       NaN       NaN       NaN       NaN   90.0576      NaN      NaN
# 16612       NaN       NaN       NaN       NaN  477.3006      NaN      NaN
# 16708       NaN       NaN       NaN       NaN   50.4360      NaN      NaN
# 16709       NaN       NaN       NaN       NaN       NaN      NaN      NaN
#
#        4/1/2014 2/1/2014 6/1/2014
# 262         NaN      NaN      NaN
# 263         NaN      NaN      NaN
# 264         NaN      NaN      NaN
# 265         NaN      NaN      NaN
# 266         NaN      NaN      NaN
# ...         ...      ...      ...
# 16610       NaN      NaN      NaN
# 16611       NaN      NaN      NaN
# 16612       NaN      NaN      NaN
# 16708       NaN      NaN      NaN
# 16709    19.593      NaN      NaN
#
# [480 rows x 33 columns]

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **STUDENT EXERCISES:**

# %% [markdown]
# <a id='manipulate'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background: #e6f2ff">
# <h2> Data Manipulation & Cleaning </h2>
#
# **Setup:**
# * Create a <a href='#copy'>copy</a> of the original dataframe for data manipluations and data cleaning
#
#
# **Example 1:** Splitting the "City, State" column into two separate columns: "City" and "State"
# * <a href='#split'> splitting strings</a>
# * <a href='#rename'> rename columns</a>
# * <a href='#addcolumns'> add new columns</a>
#
#
# **Example 2:**  clean & filter the data
#
# * <a href='#dropcolumns'>drop unneccesary or redundant columns</a>
# * <a href='#filter'>filter the data to USA only</a>
#
# **Example 3:** gathering columns to rows and rows to columns
#
# * <a href='#melt'>melt columns to rows</a>
# * <a href='#dropna'>drop nan, NULL entries</a>
# * <a href='#changetype'>adjust column data type to match assumptions</a>
# * <a href='#pivot'>pivot rows to columns</a>

# %% [markdown]
# <a id='copy'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# SETUP
#
# **Copy the dataframe**
#
# to keep the integrity of the original dataframe, create a new dataframe with a name like "cleaned_data" or another intuitive and descriptive name using [.copy()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.copy.html)

# %%
cleaned_df = df.copy()

# %% [markdown]
# <a id='split'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 1: Splitting the "City, State" column into two separate columns: "City" and "State"
#
# **use the  [.str.split()](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html) to split the "City, State" column into "City" and "State" columns**
#
# * view the data in the dataframe to see what the separator is
# * split the string into two separate columns
#     * df['column name'].str.split(separator, Limit number of splits in output, list output in separate columns)

# %%
# view the "City, State" column, to see the separator

cleaned_df["City, State"]
# Out:
# 0              Kabul,Kabul
# 1              Herat,Hirat
# 2              Herat,Hirat
# 3              Kabul,Kabul
# 4              Kabul,Kabul
#                ...
# 17526     Ndola,Copperbelt
# 17527    Bulawayo,Bulawayo
# 17528    Bulawayo,Bulawayo
# 17529    Bulawayo,Bulawayo
# 17530        Harare,Harare
# Name: City, State, Length: 17531, dtype: object

# %%
# Using , as the separator we will create a new new_string_df containing those two columns
split_string_df = cleaned_df["City, State"].str.split(",", n = 1, expand = True)

# view the results
split_string_df
# Out:
#               0           1
# 0         Kabul       Kabul
# 1         Herat       Hirat
# 2         Herat       Hirat
# 3         Kabul       Kabul
# 4         Kabul       Kabul
# ...         ...         ...
# 17526     Ndola  Copperbelt
# 17527  Bulawayo    Bulawayo
# 17528  Bulawayo    Bulawayo
# 17529  Bulawayo    Bulawayo
# 17530    Harare      Harare
#
# [17531 rows x 2 columns]

# %% [markdown]
# <a id='rename'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 1: Splitting the "City, State" column into two separate columns: "City" and "State"
#
# **rename columns**
# 0 and 1 are not very descriptive column names in our split_string_df, lets change their names to be more meaningful.
#
# * rename columns 0, 1 to "city" and "state" using [.rename()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html)
#     * examples:
#         * rename indexes/rows: <code>df.rename(index={0: "x", 1: "y", 2: "z"})</code>
#         * rename columns: <code>df.rename(columns={"A": "a", "B": "b", "C": "c"})</code>

# %%
# make sure you assign the updated column names by using df = df.rename...
split_string_df.rename(columns={0:"city", 1:"state"}, inplace=True)

# view the updated dataframe
split_string_df
# Out:
#            city       state
# 0         Kabul       Kabul
# 1         Herat       Hirat
# 2         Herat       Hirat
# 3         Kabul       Kabul
# 4         Kabul       Kabul
# ...         ...         ...
# 17526     Ndola  Copperbelt
# 17527  Bulawayo    Bulawayo
# 17528  Bulawayo    Bulawayo
# 17529  Bulawayo    Bulawayo
# 17530    Harare      Harare
#
# [17531 rows x 2 columns]

# %% [markdown]
# <a id='addcolumns'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 1: Splitting the "City, State" column into two separate columns: "City" and "State"
#
# **add new columns**
# * add two [new columns](https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html), named "city" and "state" from split_string_df to the cleaned_df
#     * <code>df['new_column_name'] = data_assigned_to_column</code>

# %%
# add the new columns
cleaned_df["city"]= split_string_df["city"]
cleaned_df["state"]= split_string_df["state"]

# view the updated dataframe columns to make sure your newly added columns are there 
# hint: they will be added at the end of the columns list
cleaned_df.columns
# Out:
# Index(['Category', 'Country', 'Customer ID', 'Customer Name', 'Discount',
#        'Market', 'Order ID', 'Order Priority', 'Postal Code', 'Product ID',
#        'Product Name', 'Profit', 'Quantity', 'Region', 'Row ID', 'Segment',
#        'Ship Mode', 'Shipping Cost', 'City, State', 'Sub-Category',
#        'Category (OLD)', '10/1/2014', '7/1/2014', '11/1/2014', '9/1/2014',
#        '1/1/2014', '12/1/2014', '8/1/2014', '5/1/2014', '3/1/2014', '4/1/2014',
#        '2/1/2014', '6/1/2014', 'city', 'state'],
#       dtype='object')

# %% [markdown]
# <a id='dropcolumns'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 2: filter the data
#
# **Drop specific columns & rows using [.drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)**
#
# There are many reasons you may wish to drop columns from your dataframe. Here are a few examples:
# * irrlevant to the analysis you are going to do
# * out of date
# * redundant information
# * non-analyzable due to high rates of Nan or empty entries
#
# drop columns:
# * <code>df = df.drop(columns=['column1', 'columns2'])</code>
# * <code>df = df.drop('column_name',axis=1)</code>
#
# drop rows:
# * <code>df = df.drop([index, index])</code>

# %%
# drop the "City, State" and 'Category (OLD)' columns from the dataframe
cleaned_df = cleaned_df.drop(columns=['City, State', 'Category (OLD)'])

# check the results in the dataframe columns list
cleaned_df.columns
# Out:
# Index(['Category', 'Country', 'Customer ID', 'Customer Name', 'Discount',
#        'Market', 'Order ID', 'Order Priority', 'Postal Code', 'Product ID',
#        'Product Name', 'Profit', 'Quantity', 'Region', 'Row ID', 'Segment',
#        'Ship Mode', 'Shipping Cost', 'Sub-Category', '10/1/2014', '7/1/2014',
#        '11/1/2014', '9/1/2014', '1/1/2014', '12/1/2014', '8/1/2014',
#        '5/1/2014', '3/1/2014', '4/1/2014', '2/1/2014', '6/1/2014', 'city',
#        'state'],
#       dtype='object')

# %% [markdown]
# <a id='filter'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 2: filter the data
#
# Let's reduce the data down to 1 country (United States) to make it easier to work with.
#
# **Filter the using .loc**
#
# <code>df = df.loc[df['column' == 'variable']</code>

# %%
# Next we will filter the data to just the USA and call the new Dataframe df_filter
cleaned_df = cleaned_df.loc[df['Country'] == "United States"]

# Here we can view df_filter
cleaned_df
# Out:
#          Category        Country Customer ID     Customer Name  Discount  \
# 2603    Furniture  United States    AB-10060   Adam Bellavance       0.0
# 2604    Furniture  United States    AB-10060   Adam Bellavance       0.2
# 2605    Furniture  United States    AB-10105     Adrian Barton       0.0
# 2606    Furniture  United States    AB-10150       Aimee Bixby       0.6
# 2607    Furniture  United States    AB-10165       Alan Barnes       0.0
# ...           ...            ...         ...               ...       ...
# 17481  Technology  United States    VM-21685   Valerie Mitchum       0.2
# 17482  Technology  United States    VP-21730      Victor Preis       0.0
# 17483  Technology  United States    VP-21760  Victoria Pisteka       0.2
# 17484  Technology  United States    WB-21850     William Brown       0.0
# 17485  Technology  United States    XP-21865      Xylona Preis       0.2
#
#       Market        Order ID Order Priority  Postal Code       Product ID  \
# 2603      US  CA-2014-107174            Low      98105.0  FUR-TA-10004575
# 2604      US  CA-2014-107174            Low      98105.0  FUR-CH-10003312
# 2605      US  CA-2014-101042         Medium      42420.0  FUR-FU-10004665
# 2606      US  CA-2014-158876         Medium      75007.0  FUR-FU-10001967
# 2607      US  CA-2014-126634         Medium      90712.0  FUR-FU-10004973
# ...      ...             ...            ...          ...              ...
# 17481     US  US-2014-101539           High      98105.0  TEC-PH-10004165
# 17482     US  CA-2014-105333           High      10011.0  TEC-PH-10001468
# 17483     US  CA-2014-159100         Medium      38401.0  TEC-AC-10003499
# 17484     US  CA-2014-138149           High      90049.0  TEC-AC-10001284
# 17485     US  US-2014-136679         Medium      77506.0  TEC-AC-10004855
#
#        ... 1/1/2014  12/1/2014  8/1/2014 5/1/2014  3/1/2014 4/1/2014 2/1/2014  \
# 2603   ...      NaN        NaN       NaN      NaN       NaN      NaN      NaN
# 2604   ...      NaN        NaN       NaN      NaN       NaN      NaN      NaN
# 2605   ...      NaN        NaN       NaN      NaN       NaN      NaN      NaN
# 2606   ...      NaN        NaN       NaN      NaN       NaN      NaN      NaN
# 2607   ...      NaN        NaN       NaN      NaN    94.200      NaN      NaN
# ...    ...      ...        ...       ...      ...       ...      ...      ...
# 17481  ...      NaN        NaN       NaN      NaN   659.976      NaN      NaN
# 17482  ...      NaN     546.06       NaN      NaN       NaN      NaN      NaN
# 17483  ...      NaN        NaN       NaN      NaN       NaN      NaN      NaN
# 17484  ...      NaN        NaN       NaN      NaN       NaN      NaN      NaN
# 17485  ...      NaN        NaN       NaN      NaN       NaN      NaN      NaN
#
#        6/1/2014           city       state
# 2603        NaN        Seattle  Washington
# 2604        NaN        Seattle  Washington
# 2605        NaN      Henderson    Kentucky
# 2606        NaN     Carrollton       Texas
# 2607        NaN       Lakewood  California
# ...         ...            ...         ...
# 17481       NaN        Seattle  Washington
# 17482       NaN  New York City    New York
# 17483       NaN       Columbia   Tennessee
# 17484     62.31    Los Angeles  California
# 17485       NaN       Pasadena       Texas
#
# [3319 rows x 33 columns]

# %% [markdown]
# <a id='melt'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 3: gathering columns to rows and rows to columns
#
# You may have noticed that there are many missing values in the columns that contain each month, ie "1/1/2014". We will pivot these values from columns to rows, creating two new columns, one for the column 12 column headers and one for the values.
#
# **gather columns into rows using [.melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)**
#
# <img src="example_images/pandas_melt.png">
#
# df_melt = pd.melt(df, id_vars = [ ], value_vars= [ ], var_name = "", value_name = "")
#
# * id_vars: Column(s) to use as identifier variables
#     * columns you want to retain/ keep intact)
# * value_vars: Column(s) to unpivot. If not specified, uses all columns that are not set as id_vars.
#     * columns to transform
# * var_name:  Name to use for the ‘variable’ column. If None it uses frame.columns.name or ‘variable’.
#     * what are the columns you want to transform (are they cities? dates? something else?
# * value_name: Name to use for the ‘value’ column.
#     * what are the values of the columns you are going to transform (cost? population? temperature? etc?)

# %%
cleaned_df.columns
# Out:
# Index(['Category', 'Country', 'Customer ID', 'Customer Name', 'Discount',
#        'Market', 'Order ID', 'Order Priority', 'Postal Code', 'Product ID',
#        'Product Name', 'Profit', 'Quantity', 'Region', 'Row ID', 'Segment',
#        'Ship Mode', 'Shipping Cost', 'Sub-Category', '10/1/2014', '7/1/2014',
#        '11/1/2014', '9/1/2014', '1/1/2014', '12/1/2014', '8/1/2014',
#        '5/1/2014', '3/1/2014', '4/1/2014', '2/1/2014', '6/1/2014', 'city',
#        'state'],
#       dtype='object')

# %%
# lets transform all the columns that are dates (assign them to value_vars). 
# Currently those columns contain sales values so lets set var_name to "order_date" and value_name to "sales"


# try to keep your formatting legible by doing like so:
df_pivot = pd.melt(cleaned_df,
                   id_vars=['Category', 'Country', 'Customer ID', 'Customer Name', 'Discount',
                            'Market', 'Order ID', 'Order Priority', 'Postal Code', 'Product ID',
                            'Product Name', 'Profit', 'Quantity', 'Region', 'Row ID', 'Segment',
                            'Ship Mode', 'Shipping Cost', 'Sub-Category','city', 'state'], 
                   value_vars=['10/1/2014', '7/1/2014', '11/1/2014', '9/1/2014','1/1/2014', '12/1/2014',
                               '8/1/2014', '5/1/2014', '3/1/2014', '4/1/2014','2/1/2014', '6/1/2014'],
                   var_name='order_date', 
                   value_name='sales')

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
# another  clean & legible way to do this would be:
#
#
# <code>columns_to_keep = ['Category', 'Country', 'Customer ID', 'Customer Name', 'Discount',
#                    'Market', 'Order ID', 'Order Priority', 'Postal Code', 'Product ID',
#                    'Product Name', 'Profit', 'Quantity', 'Region', 'Row ID', 'Segment',
#                    'Ship Mode', 'Shipping Cost', 'Sub-Category', 'City', 'State']
#
#
# columns_to_transform = ['10/1/2014', '7/1/2014', '11/1/2014', '9/1/2014', '1/1/2014',
#                         '12/1/2014', '8/1/2014', '5/1/2014', '3/1/2014', '4/1/2014',
#                         '2/1/2014', '6/1/2014']
#
# df_pivot = pd.melt_(cleaned_df,
#                     id_vars = columns_to_keep,
#                     value_vars = columns_to_transform
#                     var_name = "order_date",
#                     value_name = "sales")</code>

# %%
# We can now see the new Dataframe, df_pivot
df_pivot
# Out:
#          Category        Country Customer ID     Customer Name  Discount  \
# 0       Furniture  United States    AB-10060   Adam Bellavance       0.0
# 1       Furniture  United States    AB-10060   Adam Bellavance       0.2
# 2       Furniture  United States    AB-10105     Adrian Barton       0.0
# 3       Furniture  United States    AB-10150       Aimee Bixby       0.6
# 4       Furniture  United States    AB-10165       Alan Barnes       0.0
# ...           ...            ...         ...               ...       ...
# 39823  Technology  United States    VM-21685   Valerie Mitchum       0.2
# 39824  Technology  United States    VP-21730      Victor Preis       0.0
# 39825  Technology  United States    VP-21760  Victoria Pisteka       0.2
# 39826  Technology  United States    WB-21850     William Brown       0.0
# 39827  Technology  United States    XP-21865      Xylona Preis       0.2
#
#       Market        Order ID Order Priority  Postal Code       Product ID  \
# 0         US  CA-2014-107174            Low      98105.0  FUR-TA-10004575
# 1         US  CA-2014-107174            Low      98105.0  FUR-CH-10003312
# 2         US  CA-2014-101042         Medium      42420.0  FUR-FU-10004665
# 3         US  CA-2014-158876         Medium      75007.0  FUR-FU-10001967
# 4         US  CA-2014-126634         Medium      90712.0  FUR-FU-10004973
# ...      ...             ...            ...          ...              ...
# 39823     US  US-2014-101539           High      98105.0  TEC-PH-10004165
# 39824     US  CA-2014-105333           High      10011.0  TEC-PH-10001468
# 39825     US  CA-2014-159100         Medium      38401.0  TEC-AC-10003499
# 39826     US  CA-2014-138149           High      90049.0  TEC-AC-10001284
# 39827     US  US-2014-136679         Medium      77506.0  TEC-AC-10004855
#
#        ...   Region  Row ID      Segment       Ship Mode  Shipping Cost  \
# 0      ...     West   39465  Home Office  Standard Class         524.76
# 1      ...     West   39466  Home Office  Standard Class          47.81
# 2      ...    South   33848     Consumer  Standard Class          83.56
# 3      ...  Central   32897     Consumer    Second Class           1.54
# 4      ...     West   39961     Consumer    Second Class           4.69
# ...    ...      ...     ...          ...             ...            ...
# 39823  ...     West   33227  Home Office    Second Class          77.64
# 39824  ...     East   36882  Home Office  Standard Class          64.39
# 39825  ...    South   40289    Corporate  Standard Class           0.68
# 39826  ...     West   36007     Consumer     First Class          22.06
# 39827  ...  Central   36486     Consumer  Standard Class           8.83
#
#       Sub-Category           city       state order_date  sales
# 0           Tables        Seattle  Washington  10/1/2014    NaN
# 1           Chairs        Seattle  Washington  10/1/2014    NaN
# 2      Furnishings      Henderson    Kentucky  10/1/2014    NaN
# 3      Furnishings     Carrollton       Texas  10/1/2014    NaN
# 4      Furnishings       Lakewood  California  10/1/2014    NaN
# ...            ...            ...         ...        ...    ...
# 39823       Phones        Seattle  Washington   6/1/2014    NaN
# 39824       Phones  New York City    New York   6/1/2014    NaN
# 39825  Accessories       Columbia   Tennessee   6/1/2014    NaN
# 39826  Accessories    Los Angeles  California   6/1/2014  62.31
# 39827  Accessories       Pasadena       Texas   6/1/2014    NaN
#
# [39828 rows x 23 columns]

# %% [markdown]
# <a id='dropna'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 3: gathering columns to rows and rows to columns
#
# **remove rows with missing values with [.dropna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)**
#
# For columns of particular importance may wish to exclude rows that have missing values to do this we use dropna()
#
# example:
#     <code>df.dropna(subset=['column'], inplace=True)</code>

# %%
# drop rows with empty values in the 'sales' column
df_pivot.dropna(subset=['sales'],inplace=True)

# %% [markdown]
# <a id='changetype'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 2: filter the data
#
# **change column datatype with [.astype()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html)**
#
# Some columns may be read into the dataframe as the incorrect data type and you may want to fix them or change them for a specific analysis. If you noticed above, the column "Postal Code" is being read as a float type when really it should be an int, but we can convert it to int using .astype()
#
# <code>df['column'] = df['column'].astype(desired_type)</code>

# %%
#  change column "Postal Code" from a float to an int
cleaned_df['Postal Code'] = cleaned_df['Postal Code'].astype(int)

# %% [markdown]
# <a id='pivot'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 3: gathering columns to rows and rows to columns
#
# **we can unpivot rows into columns using [.pivot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html)**
#
# <img src="example_images/pandas_pivot.png">
#
#
# example:
#     df.pivot(columns = ['columns])

# %%
# get just the 'state' and 'Category' columns and turn the 'Category' column into rows 
df_un_pivot = df_pivot[['state', 'Category']].pivot(columns='Category')

# view the resulting dataframe
df_un_pivot
# Out:
#                  state
# Category     Furniture Office Supplies  Technology
# 18        Rhode Island             NaN         NaN
# 19        Rhode Island             NaN         NaN
# 21        Rhode Island             NaN         NaN
# 22        Rhode Island             NaN         NaN
# 38          California             NaN         NaN
# ...                ...             ...         ...
# 39801              NaN             NaN    Michigan
# 39811              NaN             NaN  New Jersey
# 39812              NaN             NaN   Tennessee
# 39813              NaN             NaN   Tennessee
# 39826              NaN             NaN  California
#
# [3319 rows x 3 columns]

# %% [markdown]
# <a id='plot'></a>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **STUDENT EXERCISES:**

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background: #e6f2ff">
# <h2>Data Aggregation & Plotting </h2>
#
# **SETUP:**
# * <a href='#COGScolumn'> create a column wih the cost of goods</a>
#
# **Example 1:** Get categorical data frequency counts with .crosstab
# * <a href='#crosstab'> get a count of categorical variables</a>
#
# **Example 2:** Aggregate the data using .pivot_table()
# * <a href='#pivot_table'> flexible aggregation of categorical variables</a>
#
#
# **Example 3:** Aggregate data using .groupby and .agg
# * <a href='#groupby'> get the sum of a field using groupby and agg</a>
# * <a href='#plot_agg'> plot the results</a>
#
#
# **Example 4:** Improve plotting by sorting values
# * <a href='#sort_values'>use sort_values() </a>
#
# NOTE: while this tutorial uses pandas built in plotting functions there are many better packages for plotting, the [Seaborn](https://seaborn.pydata.org/) package workes especially well with pandas dataframe and other tabular style data

# %% [markdown]
# <a id='COGScolumn'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# SETUP: Create a cost of goods column
#
# We can create a new field showing the Cost of Goods Sold or 'COGS' by subracting the "Profit" column from "Sales".Pandas does this efficiently using vectorized operations, so we don't need to write a loop

# %%
# create the cost of goods column
df_pivot['COGS'] = df_pivot['sales'] - df_pivot['Profit']

# %% [markdown]
# <a id='crosstab'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 1:
#
# **Get frequency counts with <code>[.crosstab()](https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html)</code>**
#
# Cross-tabulations or contingency tables are tables used to describe relationships between two categorical variables. The table displays the frequency distribution of the variables. This is a very easy built in function to use, but the downside is that it is not flexible. It only offers frequency counts.
#
# <code>x_tab = pd.crosstab(df['index_column'], columns=df['column_column'])</code>
# * the 'index_column' is the column that will become the index of your new dataframe
# * the 'column_column' will become multiple columns separated by category

# %%
xtab = pd.crosstab(df_pivot['Order Priority'], columns=df_pivot['Ship Mode'])

# view the results
xtab
# Out:
# Ship Mode       First Class  Same Day  Second Class  Standard Class
# Order Priority
# Critical                114        43            61               0
# High                    278        97           274             437
# Low                       0         0             0             163
# Medium                  181        46           322            1303

# %% [markdown]
# <a id='pivot_table'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 2:
#
# **aggregate data using [.pivot_table()](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)**
# the .pivot_table() function allows us to construct quick aggregate tables using categorical variables. This is slightly more complicated than crosstab but it offers more flexibility in aggregator functions.
#
# In this example we want to be able to count how many orders there are for the different Order Priorities and different shipping mode levels.
#
#
# example:
# <code>pd.pivot_table(df, values = [ ], index = [ ], columns = [ ], aggfunct = )</code>
#
# * values: column to aggregate
# * index: column to use as index
# * columns: column to use as the columns
# * aggfunc: the type of aggregator function to use
#     * examples: 'count', 'Mean': np.mean, 'Sigma': np.std

# %%
# To see how this works lets make something similar to our crosstab with counts! 

# Lets use Order ID as our values because it's unique
# set our index to "Order Priority"
# use "Ship Mode" as our columns
# and lets count as our aggregate function to count how many 
# Order IDs there are for each order priorty and shipping mode

pd.pivot_table(df_pivot, values =['Order ID'], index=['Order Priority'], columns=['Ship Mode'], aggfunc='count')
# Out:
#                   Order ID
# Ship Mode      First Class Same Day Second Class Standard Class
# Order Priority
# Critical             114.0     43.0         61.0            NaN
# High                 278.0     97.0        274.0          437.0
# Low                    NaN      NaN          NaN          163.0
# Medium               181.0     46.0        322.0         1303.0

# %% [markdown]
# <a id='groupby'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 3:
#
# **aggregate data using [.groupby()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html) and [.agg()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html)**
#
# groupby allows you to group a dataframe using a mapper or by a Series of columns. A groupby operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.
#
# <img src="example_images/pandas_groupby.png">
#
# Pandas has a set of charting tools built into the library. By aggregating data using df.grouby().agg() we can quickly construct visualizations, for example here using df.plot.bar()

# %%
# subset the dataframe to just "Region" and "COGS" (cost of goods) from the df_pivot dataframe
# group by the "Region" column
# use "sum" as the aggregator to get the total cost of all goods for a given region

agg_df = df_pivot[['Region', 'COGS']].groupby(by = 'Region').agg(['sum'])

# view the resulting dataframe
agg_df
# Out:
#                 COGS
#                  sum
# Region
# Central  139547.2840
# East     180044.0698
# South    114116.2564
# West     206731.8999

# %% [markdown]
# <a id='plot_agg'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 4:
#
# **plot the results of the aggregation**
#
# you can quickly create visualizations using pandas built in plotting functions such as [.plot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
#
# This has many of the same built in arguments that the matplotlib pyplot package offers:
# * x: label or position, default None (Only used if data is a DataFrame.)
# * y: label, position or list of label, positions, default None (Allows plotting of one column versus another. Only used if data is a DataFrame.)
# * kind: The kind of plot to produce. Options are:
#     * ‘line’ : line plot (default)
#     * ‘bar’ : vertical bar plot
#     * ‘barh’ : horizontal bar plot
#     * ‘hist’ : histogram
#     * ‘box’ : boxplot
#     * ‘kde’ : Kernel Density Estimation plot
#     * ‘density’ : same as ‘kde’
#     * ‘area’ : area plot
#     * ‘pie’ : pie plot
#     * ‘scatter’ : scatter plot (DataFrame only)
#     * ‘hexbin’ : hexbin plot (DataFrame only)
#
# * xlabel: Name to use for the xlabel on x-axis. Default uses index name as xlabel, or the x-column name for planar plots.
# * ylabel: Name to use for the ylabel on y-axis. Default will show no ylabel, or the y-column name for planar plots.
#
#
# example:
# <code>df.plot(x = 'xcolumn', y= 'ycolumn', kind = "box", xlabel= 'x value units', ylabel = 'y value units')</code>

# %%
# plot the agg_df as a barplot, since the df only has one column('COGS') no need to specify x & y
agg_df.plot(kind='bar', xlabel = "Region", ylabel = "COGS")

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# PROTIP:
#
# You can either do the grouping and aggregation to produce a dataframe and then plot the results from that dataframe (separating the grouping & agg from the plotting)  as we did above.
#
#  ~ Or ~  you can call the plot directly at the end of the grouping and aggregation. Whatever is more readable to intuitive is the method you should use.
#
#
# Example:
#
# <code>df_pivot[['Region', 'COGS']].groupby(by = 'Region').agg(['sum']).plot((kind='bar', xlabel = "Region", ylabel = "COGS")</code>

# %% [markdown]
# <a id='sort_values'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# EXAMPLE 4 cont.: **Improve your plots by sorting the values**
#
# you can use [.sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html) to sort your dataframe by the the values of a particular column or columns. Sorting the values of your dataframe before plotting creates more interpretable plots.
#
# example:
#
# <code>df.sort_values[by=['column1', 'column2'], ascending = boolean, inplace= boolean)</code>

# %%
# we want a horizontal bar plot of the sum of sales by state
# Similar to example 2, subset df_pivot to just "state" and "sales" 
# then groupby 'state' & use 'sum' as the aggregator
df_agg = df_pivot[['state','sales']].groupby('state').agg(['sum'])

# then sort the values by both 'Sales' and 'sum'
df_agg.sort_values(by=[('sales', 'sum')], ascending = False, inplace=True)

# finally plot the dataframe using the built-in pandas functionality
# figsize can be used to increase the size of the visualization
df_agg.plot(kind='barh', figsize=(10,10))

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **STUDENT EXERCISES:**
# <p>1) What State has the highest Profit in the US?
# <p>2) Which Customer had the 3rd highest total Sales?
#
# HINT: use the index to easily access sorted data by location

# %%
# aggregate the correct data & sort it
profit_by_state = df_pivot[['state', 'Profit']].groupby('state').agg(['sum'])
profit_by_state.sort_values(by=[('Profit', 'sum')], ascending = False, inplace=True)

# print state with highest profit
print("Most profitable state: " + profit_by_state.index[0])
# Out:
# Most profitable state: California

# %%
# same process as above
sales_by_cust = df_pivot[['Customer Name', 'sales']].groupby('Customer Name').agg(['sum'])
sales_by_cust.sort_values(by=[('sales', 'sum')], ascending = False, inplace=True)

# get the 3rd row
print("Customer with 3rd highest total sales: " + sales_by_cust.index[2])
# Out:
# Customer with 3rd highest total sales: Hunter Lopez

# %% [markdown]
# <a id='table'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background: #e6f2ff">
# <h2> Table Manipulation </h2>
#
# **<a href='#create_table'> Creating DataFrames from Scratch:</a>**
# * <a href='#table_from_array'> from an array</a>
# * <a href='#table_from_lists'> from a lists</a>
# * <a href='#table_from_dict'> from a dictionary</a>
#
#
# **Combining DataFrames**
# * <a href='#concat'>append tables with the same structure using .concat</a>
# * <a href='#reset_index'>reset a table index</a>
# * <a href='#merge_df'> merging dataFrames</a>
# * <a href='#merge_left_right'> left and right merges</a>
# * <a href='#merge_inner_outer'> inner and outer merges</a>
#
# **Saving DataFrames**
# * <a href='#save_df'>save to excel</a>
# * <a href='#save_df'>save to .csv</a>

# %% [markdown]
# <a id='create_table'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Creating a DataFrame**
#
# You can create dataframes from scratch by using [pd.DataFrame()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)
#
# Because dataFrames are tabular, your data will need column names. This usually means that creating a dataframe from scratch will require some combination of using arrays, lists or dictionaries.

# %% [markdown]
# <a id='table_from_array'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Create a dataframe from a numpy array**
#
# When creating a dataframe from an array it's important that you know what each dimension of your array represents. Lists and dictionaries are a little more self-documenting in that way, but using arrays can be very efficient.
#
# You must always provide the correct number of column labels to match your array dimensions
# * <code>pd.DataFrame(data_array, columns=['column_1','column_2'...])</code>
#
#
# Note: for this example we will have to create a numpy array (using <code>numpy.random.rand</code>), however in the real world you would already have your array that you'd like to turn into a dataframe.

# %%
# first create the array using numpy random.rand(rows,columns)
data_array = np.random.rand(25,3) 
data_array
# Out:
# array([[0.43711576, 0.46377844, 0.29022396],
#        [0.94340246, 0.73204285, 0.80870215],
#        [0.76110974, 0.78681481, 0.91656701],
#        [0.16624555, 0.48551318, 0.61829145],
#        [0.19700373, 0.80825042, 0.37537146],
#        [0.44264734, 0.99523983, 0.54825967],
#        [0.2373417 , 0.24969707, 0.08440092],
#        [0.94940391, 0.93228362, 0.59694214],
#        [0.37384943, 0.96455491, 0.67446319],
#        [0.11515533, 0.15863205, 0.67058484],
#        [0.69931307, 0.26985845, 0.11776047],
#        [0.82116173, 0.81645362, 0.24928066],
#        [0.26877841, 0.58065407, 0.05319247],
#        [0.46758355, 0.59738288, 0.71457403],
#        [0.66437678, 0.46692905, 0.27822076],
#        [0.16968915, 0.95550958, 0.4525378 ],
#        [0.29096223, 0.06892   , 0.61380366],
#        [0.41881597, 0.00310305, 0.57979426],
#        [0.80083834, 0.02158672, 0.13051184],
#        [0.36010707, 0.56707612, 0.95675252],
#        [0.66137901, 0.55441621, 0.38265836],
#        [0.75488003, 0.40060986, 0.77720231],
#        [0.5958384 , 0.38744677, 0.04100545],
#        [0.52112793, 0.15229061, 0.70143039],
#        [0.13314345, 0.4388891 , 0.74050308]])

# %%
# create the dataframe, assigning data first and then the columns
# our array is 25 rows x 3 columns so we must provide 3 column labels
array_df = pd.DataFrame(data_array, columns=['column_1','column_2','column_3'])

#view the dataframe
array_df
# Out:
#     column_1  column_2  column_3
# 0   0.437116  0.463778  0.290224
# 1   0.943402  0.732043  0.808702
# 2   0.761110  0.786815  0.916567
# 3   0.166246  0.485513  0.618291
# 4   0.197004  0.808250  0.375371
# 5   0.442647  0.995240  0.548260
# 6   0.237342  0.249697  0.084401
# 7   0.949404  0.932284  0.596942
# 8   0.373849  0.964555  0.674463
# 9   0.115155  0.158632  0.670585
# 10  0.699313  0.269858  0.117760
# 11  0.821162  0.816454  0.249281
# 12  0.268778  0.580654  0.053192
# 13  0.467584  0.597383  0.714574
# 14  0.664377  0.466929  0.278221
# 15  0.169689  0.955510  0.452538
# 16  0.290962  0.068920  0.613804
# 17  0.418816  0.003103  0.579794
# 18  0.800838  0.021587  0.130512
# 19  0.360107  0.567076  0.956753
# 20  0.661379  0.554416  0.382658
# 21  0.754880  0.400610  0.777202
# 22  0.595838  0.387447  0.041005
# 23  0.521128  0.152291  0.701430
# 24  0.133143  0.438889  0.740503

# %% [markdown]
# <a id='table_from_lists'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **dataframe from lists**
#
# You can easily make a dataframe from multiple lists and a dictionary.
# * Each list represents a column of data.
# * dictionary keys represent column names
# * dictionary values are the lists that contain all the data/rows
#
# Note: all lists must be the same length!

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
# For the lists and dictionaries examples we will make a dataframe of adoptable pets!

# %%
# first make the lists, we will have 4 entries for each list
name = ['Oreo','Squid','Mrs Noris', 'Dazzler']
age_months = [5, 18, 12, 9]


# then assign the lists to appropriate column names using dictionary keys
dict_of_lists = {'name': name,
                 'age_months': age_months}

# finally create a dataframe using the dictionary
dict_df1 = pd.DataFrame(dict_of_lists)
dict_df1
# Out:
#         name  age_months
# 0       Oreo           5
# 1      Squid          18
# 2  Mrs Noris          12
# 3    Dazzler           9

# %%
# Another way to make a dataframe using lists and dictionaries is to do the dictionary
# assignment within the dataframe creation call. This just cuts out a middle step

names = ['Cheddar', 'Zuko']
age_months = [7, 21]

dict_df2 = pd.DataFrame({'name':names,
                         'age_months': age_months})
dict_df2
# Out:
#       name  age_months
# 0  Cheddar           7
# 1     Zuko          21

# %% [markdown]
# <a id='table_from_dict'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **dataframe from list of dictionaries**
#
# You can also create a single list that contains multiple dictionaries.
# * each dictionary represents a row
# * each key represents a column.
#
# note: you must use the exact same keys in all dictionaries using this method.

# %%
list_of_dicts = [
    {'name': 'Oreo',      'species': 'dog'},
    {'name': 'Dazzler',   'species': 'cat'},
    {'name': 'Templeton', 'species': 'rat'},
]

list_df = pd.DataFrame(list_of_dicts)
list_df
# Out:
#         name species
# 0       Oreo     dog
# 1    Dazzler     cat
# 2  Templeton     rat

# %% [markdown]
# <a id='concat'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Append dataframes using concat**
#
# you can append one dataframe to another if they have the same structure(i.e. same columns OR same indexes) using [.concat()](https://pandas.pydata.org/docs/reference/api/pandas.concat.html)
#
# concatenate rows:
#     <code>pd.concat([df1,df2])</code>
#
# <img src="example_images/pandas_concat_rows.png">
#
# concatenate columns:
#     <code>pd.concat([df1,df2], axis=1)</code>
# <img src="example_images/pandas_concat_columns.png">
#
# If you've appended the dataframe by adding rows, you may wish to reset the index so specific index numbers aren't repeated. This is easily achievable with [.reset_index()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html).
#
#  * Use <code>drop=True</code> if it's not necessary to maintain a column with the original indexes.

# %%
# dict_df1 and dict_df2 have the same structure without redundancy
# so they're good candidates for concatenation. 

pd.concat([dict_df1, dict_df2])
# Out:
#         name  age_months
# 0       Oreo           5
# 1      Squid          18
# 2  Mrs Noris          12
# 3    Dazzler           9
# 0    Cheddar           7
# 1       Zuko          21

# %% [markdown]
# <a id='reset_index'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Resetting the index**
#
# If you've appended the dataframe by adding rows and your index isn't a unique id, you may wish to reset the index so index numbers aren't repeated. This is easily achievable with [.reset_index()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html).
#
#  * Use <code>drop=True</code> if it's not necessary to maintain a column with the original indexes.

# %%
# Lets try concatinating again but resetting the index while we do so

pd.concat([dict_df1, dict_df2]).reset_index(drop=True)
# Out:
#         name  age_months
# 0       Oreo           5
# 1      Squid          18
# 2  Mrs Noris          12
# 3    Dazzler           9
# 4    Cheddar           7
# 5       Zuko          21

# %% [markdown]
# <a id='merge_df'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Merging DataFrames**
#
# Needing to merge or join dataframes is a very common occurance in data analysis. Frequently one table contains a specific type of data while another table contains some other data, and you wish to combine that information.
#
# There are several different ways to merge DataFrames. The most common way is using [.merge()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)
#
# Important function arguments:
# * <code>how</code> determines the way the dataframes are merged. There are 4 basic options:
#     * <code>'left'</code> & <code>'right'</code>
#     * <code>'inner'</code>(default) & <code>'outer'</code>
#
# * <code>on</code> argument identifies which column(s) are common across both dataframes and should be used as the index to merge the dataframes on
#     * in the example images below 'x1' is the common column that would be used
#         * <code>on ='x1'</code>

# %% [markdown]
# <a id='merge_left_right'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Left and Right merges**
#
# For <code>'left'</code> and <code>'right'</code> merges, the order that you list the dataframes in the <code>.merge()</code> function matters. The first dataframe listed is the 'left' dataframe and the second is the 'right' dataframe.
#
# * left merge:
#     * Joins matching rows from df_right to df_left, retaining all the information from the df_left.
#     * <code>left_merge_df = pd.merge(df_left, df_right, how='left', on='x1')</code>
#
# <img src="example_images/pandas_join_left.png">
#
# * right merge example:
#     * Joins matching rows from df_left to df_right, retaining all the information from the df_right
#     * <code>right_merge_df = pd.merge(left_df, right_df, how='right', on='x1')</code>
#
# <img src="example_images/pandas_join_right.png">

# %%
# Lets do a LEFT join 
# dict_df1 which contains information on animal 'name' and 'age_months'
# list_df contains 'name' and 'species'

pd.merge(dict_df1, list_df, how = 'left', on ='name')
# Out:
#         name  age_months species
# 0       Oreo           5     dog
# 1      Squid          18     NaN
# 2  Mrs Noris          12     NaN
# 3    Dazzler           9     cat

# %%
# Try a right join with the same dataframes! 

pd.merge(dict_df1, list_df, how = 'right', on ='name')
# Out:
#         name  age_months species
# 0       Oreo         5.0     dog
# 1    Dazzler         9.0     cat
# 2  Templeton         NaN     rat

# %% [markdown]
# <a id='merge_inner_outer'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Inner and Outer Merges**
#
# For <code>'inner'</code> and <code>'outer'</code> merges, the order of the dataframes does not matter. Instead the inner and outer merges are based on what is common between both dataframes.
#
# * inner merge:
#     * Join data and retains only rows found in both dataframes.
#     * <code>inner_merge_df = pd.merge(df1, df2, how='inner', on='x1')</code>
#
# <img src="example_images/pandas_join_inner.png">
#
# * outer merge:
#     * Joins dataframes and retains all values, all rows.
#     * <code>outer_merge_df = pd.merge(df1, df2, how='outer', on='x1')</code>
#
# <img src="example_images/pandas_join_outer.png">

# %%
# Lets try an outer merge with those same dataframes

pd.merge(dict_df1, list_df, how = 'outer', on ='name')
# Out:
#         name  age_months species
# 0       Oreo         5.0     dog
# 1      Squid        18.0     NaN
# 2  Mrs Noris        12.0     NaN
# 3    Dazzler         9.0     cat
# 4  Templeton         NaN     rat

# %% [markdown]
# <a id='save_df'></a>

# %% [markdown]
# <div style="padding: 5px; padding-left: 10px; background:#e6e6e6">
#
# **Saving dataframes**
#
# Just like loading dataframes, there are many different formats that you can save a dataframe to. We will just show you .csv and .xls but to see a complete list please check out the [input/output documentation here](https://pandas.pydata.org/docs/reference/io.html):
#
# * [.to_csv()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)
#     * <code>df.to_csv('df_save_name.csv')</code>
#
# * [.to_excel()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html#pandas.DataFrame.to_excel)
#     * <code>df.to_excel('df_save_name.xlsx')</code>
#
#
# by default the save functions will save to your working directory. You must specify a path if you wish to save your dataframe elsewhere.

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **STUDENT EXERCISES:**
